# %%
import seaborn as sns 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
var = pd.read_csv("books.csv")
sns.displot(var["Genre"])

# %%
sns.displot(var["User Rating"], bins=[3.4, 3.6,4.0] )

# %%
sns.displot(var["User Rating"], kde= True)

# %%
sns.displot(var["User Rating"], color ='g')

# %%
sns.displot(var["User Rating"], log_scale= True)
